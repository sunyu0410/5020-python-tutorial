# %% [markdown]
# # Reading Materials and Exercise III - Matplotlib
#
# Have a look at the examples of Matplotlib and inform youself what it can do:
# https://matplotlib.org/stable/gallery/index

# %%
# Set up
# Do not change
# Generate some data

import numpy as np
import matplotlib.pyplot as plt

np.random.seed(123)

scales = [5, 6, 7, 8]

xs = [np.random.random(100) * scale - scale/2 for scale in scales]
_ = [x.sort() for x in xs]

noises = [np.random.normal(0, 3, 100) for i in range(4)]
ys = [np.exp(x) + noise for (x, noise) in zip(xs, noises)]

ys[1] = ys[1] + 10
ys[2] = -ys[2] + ys[2].max()

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# Use `plt.plot` to make the following figure.

# %%
# Your answer goes here
# Out:
# Text(0.5, 1.0, 'Figure 1')

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# Use `plt.subplots` to make the following figure.

# %%
# Your answer goes here
